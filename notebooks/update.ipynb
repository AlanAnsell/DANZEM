# %%
from danzem import update

update.Update()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d94c2ac2e6fa> in <module>()
#       1 from danzem import update
#       2
# ----> 3 update.Update()
#
# ~\Miniconda2\envs\python36\lib\site-packages\danzem\update.py in Update()
#     157
#     158 def Update():
# --> 159     UpdateBids()
#     160     UpdateOffers()
#     161     UpdateLGP()
#
# ~\Miniconda2\envs\python36\lib\site-packages\danzem\update.py in UpdateBids()
#     104 def UpdateBids():
#     105     url_fn = MakeDayUrlFn(BID_URL_PREFIX_, 'Bids')
# --> 106     UpdateDataset('Bids', data.GetBidsDir(), url_fn, BID_DATA_START_)
#     107
#     108
#
# ~\Miniconda2\envs\python36\lib\site-packages\danzem\update.py in UpdateDataset(name, file_dir, url_fn, start_date, url_suffixes)
#      95     print('Downloading %d new %s files' % (len(to_download), name))
# ...
